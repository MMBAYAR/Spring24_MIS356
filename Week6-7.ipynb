# %% [markdown]
# <a href="https://colab.research.google.com/github/MMBAYAR/Spring24_MIS356/blob/main/Week6-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#. Solution to Assignment
#.   importing the pandas module
import pandas
#.   using the read_csv() function and plugging in the file path I create a variable with the dataset in it
auto = pandas.read_csv('/content/Auto.csv')

# %%
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %% [markdown]
# Vehicles with 3 cylinder engines,
# Vehicles with 4 to 6 cylinder engines,
# Vehicles with more than 100 horsepower with less than 4 cylinder engines,
# Vehicles produced after the year 2000 or before the year 1980,
# The 3 least petrol consuming Asian-make vehicles

# %%
#. w/ 3 cylinder
auto[ auto.cylinders == 3 ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 71   19.0          3          70.0         97    2330          13.5    72
# 111  18.0          3          70.0         90    2124          13.5    73
# 243  21.5          3          80.0        110    2720          13.5    77
# 334  23.7          3          70.0        100    2420          12.5    80
#
#      origin             name
# 71        3  mazda rx2 coupe
# 111       3        maxda rx3
# 243       3       mazda rx-4
# 334       3    mazda rx-7 gs

# %%
auto[ auto['cylinders'] == 3 ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 71   19.0          3          70.0         97    2330          13.5    72
# 111  18.0          3          70.0         90    2124          13.5    73
# 243  21.5          3          80.0        110    2720          13.5    77
# 334  23.7          3          70.0        100    2420          12.5    80
#
#      origin             name
# 71        3  mazda rx2 coupe
# 111       3        maxda rx3
# 243       3       mazda rx-4
# 334       3    mazda rx-7 gs

# %%
auto[ auto.iloc[:,1] == 3 ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 71   19.0          3          70.0         97    2330          13.5    72
# 111  18.0          3          70.0         90    2124          13.5    73
# 243  21.5          3          80.0        110    2720          13.5    77
# 334  23.7          3          70.0        100    2420          12.5    80
#
#      origin             name
# 71        3  mazda rx2 coupe
# 111       3        maxda rx3
# 243       3       mazda rx-4
# 334       3    mazda rx-7 gs

# %%
#. /w 4 to 6 cylinders
auto[ (auto.cylinders >= 4) (auto.cylinders <= 6) ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0b88b4a5c9d1> in <cell line: 2>()
#       1 #. /w 4 to 6 cylinders
# ----> 2 auto[ (auto.cylinders >= 4) (auto.cylinders <= 6) ]
#
# TypeError: 'Series' object is not callable

# %%
auto[ (auto.cylinders >= 4) & (auto.cylinders <= 6) ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 14   24.0          4         113.0         95    2372          15.0    70
# 15   22.0          6         198.0         95    2833          15.5    70
# 16   18.0          6         199.0         97    2774          15.5    70
# 17   21.0          6         200.0         85    2587          16.0    70
# 18   27.0          4          97.0         88    2130          14.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                   name
# 14        3  toyota corona mark ii
# ...

# %%
 auto[ (auto.cylinders >= 4) & (auto.cylinders <= 6) ].cylinders.unique()
# Out:
# array([4, 6, 5])

# %%
#. higher than 100hp and engines w/ less than 4 cylinders
auto[ (auto.horsepower > 100) (auto.cylinders < 4) ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-bd9a5de530ee> in <cell line: 2>()
#       1 #. higher than 100hp and engines w/ less than 4 cylinders
# ----> 2 auto[ (auto.horsepower > 100) (auto.cylinders < 4) ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      79         other = item_from_zerodim(other)
#      80
# ---> 81         return method(self, other)
#      82
#      83     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6094
# ...

# %%
auto.horsepower.unique()
#. 2 issues:
#.   '?'
#.   numeric values given as strings
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
#.   '?'
auto.horsepower = auto.horsepower.replace( '?', 0 )

# %%
#.   numeric values given as strings
auto.horsepower = [ int(i) for i in auto.horsepower ]

# %%
auto.cylinders.unique()
#. no issues; all numeric values
# Out:
# array([8, 4, 6, 3, 5])

# %%
auto[ (auto.horsepower > 100) & (auto.cylinders < 4) ]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 243  21.5          3          80.0         110    2720          13.5    77
#
#      origin        name
# 243       3  mazda rx-4

# %%
#. Vehicles produced after the year 2000 or before the year 1980
auto.year.unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
auto[ (auto.year > 2000) | (auto.year < 80) ]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 304  37.3          4          91.0          69    2130          14.7    79
# 305  28.4          4         151.0          90    2670          16.0    79
# 306  28.8          6         173.0         115    2595          11.3    79
# 307  26.8          6         173.0         115    2700          12.9    79
# 308  33.5          4         151.0          90    2556          13.2    79
#
#      origin                       name
# ...

# %%
#  The 3 least petrol consuming Asian-make vehicles

auto.origin.unique()
# Out:
# array([1, 3, 2])

# %%
#.    Asian make cars
auto[ auto.origin == 3 ]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 14   24.0          4         113.0          95    2372          15.0    70
# 18   27.0          4          97.0          88    2130          14.5    70
# 29   27.0          4          97.0          88    2130          14.5    71
# 31   25.0          4         113.0          95    2228          14.0    71
# 53   31.0          4          71.0          65    1773          19.0    71
# ..    ...        ...           ...         ...     ...           ...   ...
# 381  34.0          4         108.0          70    2245          16.9    82
# 382  38.0          4          91.0          67    1965          15.0    82
# 383  32.0          4          91.0          67    1965          15.7    82
# 384  38.0          4          91.0          67    1995          16.2    82
# 389  32.0          4         144.0          96    2665          13.9    82
#
#      origin                   name
# ...

# %%
#.     Sorting Asian make cars with respect to mpg (descending)

auto[ auto.origin == 3 ].sort_values( ['mpg',], ascending = False )
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 322  46.6          4          86.0          65    2110          17.9    80
# 329  44.6          4          91.0          67    1850          13.8    80
# 324  40.8          4          85.0          65    2110          19.2    80
# 247  39.4          4          85.0          70    2070          18.6    78
# 343  39.1          4          79.0          58    1755          16.9    81
# ..    ...        ...           ...         ...     ...           ...   ...
# 108  20.0          4          97.0          88    2279          19.0    73
# 123  20.0          6         156.0         122    2807          13.5    73
# 210  19.0          6         156.0         108    2930          15.5    76
# 71   19.0          3          70.0          97    2330          13.5    72
# 111  18.0          3          70.0          90    2124          13.5    73
#
#      origin                 name
# 322       3            mazda glc
# ...

# %%
#.     The first 3 in sorted DataFrame

sorted = auto[ auto.origin == 3 ].sort_values( ['mpg',], ascending = False )

sorted.iloc[ :3 , : ]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 322  46.6          4          86.0          65    2110          17.9    80
# 329  44.6          4          91.0          67    1850          13.8    80
# 324  40.8          4          85.0          65    2110          19.2    80
#
#      origin                 name
# 322       3            mazda glc
# 329       3  honda civic 1500 gl
# 324       3           datsun 210

# %% [markdown]
# #Supervised Learning Workshop 1.1:
#
# ##Generating data with some noise, drawing samples, plotting

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#. predetermining plot format features
plt.rcParams['figure.figsize'] = [6,3.875]
plt.rcParams['font.size'] = 12
plt.rcParams['figure.dpi'] = 200
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

# %%
#. Generating the predictos (X)
X = np.linspace( -1.5, 7, 10**5 )

#. Defining a trig function with a slightly positive trend
def f(x):
  return np.sin( (x-2)**2 ) + 0.4*x
#.   This is the regression function, the function that best explains the data

#. Generating responses with noise (mathing number of random additions to the reg.func.)
y = f(X) + np.random.normal(loc = 0, scale = 0.25, size = 10**5)

# %%
#. Plotting the regression function in red
sns.lineplot(
    #. Values for the horizontal axis:
    x = X,
    #. Values for the vertical axis:
    y = f(X),
    color = 'red',
    label = '$f(x)$'
)

#. Plotting the responses in blue:
sns.scatterplot(
    #. Values for the horizontal axis:
    x = X,
    #. Values for the vertical axis:
    y = y,
    color = 'blue',
    alpha = .05,
    marker = 'x',
    label = '$y$'
)

#. Renaming axes
plt.xlabel( '$x$' )
plt.ylabel( '$y$' )

#. Plot title
plt.title( 'A combination regression function and the observations' )

#. Downloading image as a .png file
# Out:
# Text(0.5, 1.0, 'A combination regression function and the observations')

# %% [markdown]
# ##Since we have too many points ($10^5$), they overlap and form a cloud wrapping the regression function
#
# ##It is best we draw out a representative sample with reasonable size

# %%
#  DRAWING A RANDOM SAMPLE OF 50 DATA

#.   Converting a numpy array into a pandas Series
X = pd.Series( X )
y = pd.Series( y )

#    A random sample, the fraction is sample_size / population_size
sample_size = 250
population_size = len(X)

X_sample = X.sample( frac = sample_size / population_size )

#.   Using the indices of X_sample, defining the correspongind responses
y_sample = y.iloc[ list(X_sample.index) ]

# %%
#. Plotting the responses again...
#.   Plotting the regression function in red
sns.lineplot(
    #. Values for the horizontal axis:
    x = X,
    #. Values for the vertical axis:
    y = f(X),
    color = 'red',
    alpha = .1,
    label = '$f(x)$'
)

#.   Plotting the responses in blue:
sns.scatterplot(
    #. Values for the horizontal axis:
    x = X_sample,
    #. Values for the vertical axis:
    y = y_sample,
    color = 'blue',
    marker = 'x',
    label = '$y_{sample}$'
)

#.   Plotting deviations from the reg. function
for i in X_sample.index:
  sns.lineplot(
  x = [X_sample[i],X_sample[i]],
  y = [y_sample[i],f( X_sample[i] )],
  color = 'blue',

  )

#. Renaming axes
plt.xlabel( '$x_{sample}$' )
plt.ylabel( '$y_{sample}$' )

#. Plot title
plt.title( 'A combination regression function and the observations' )
# Out:
# Text(0.5, 1.0, 'A combination regression function and the observations')

# %% [markdown]
# ##. Simple linear regression for predicting y values

# %%
#. import sklearn linear regressor
from sklearn.linear_model import LinearRegression
#. import sklearn metrics/mean squared eror
from sklearn.metrics import mean_squared_error as mse

# %%
#. creating a model
model = LinearRegression().fit(
                               np.array(X_sample).reshape(-1,1),
                               y_sample
                              )
#. prediction are my assumed y values
model.predict( np.array(X_sample).reshape(-1,1) )

sns.lineplot(
x = X_sample,
y = model.predict( np.array(X_sample).reshape(-1,1) ),
label = 'Linear_regressor'
)




###############PREVIOS PLOT##################

#. plotting my model
#. Plotting the responses again...
#.   Plotting the regression function in red
sns.lineplot(
    #. Values for the horizontal axis:
    x = X,
    #. Values for the vertical axis:
    y = f(X),
    color = 'red',
    alpha = .1,
    label = '$f(x)$'
)

#.   Plotting the responses in blue:
sns.scatterplot(
    #. Values for the horizontal axis:
    x = X_sample,
    #. Values for the vertical axis:
    y = y_sample,
    color = 'blue',
    marker = 'x',
    label = '$y_{sample}$'
)

#.   Plotting deviations from the reg. function
for i in X_sample.index:
  sns.lineplot(
  x = [X_sample[i],X_sample[i]],
  y = [y_sample[i],f( X_sample[i] )],
  color = 'blue',

  )

#. Renaming axes
plt.xlabel( '$x_{sample}$' )
plt.ylabel( '$y_{sample}$' )

#. Plot title
plt.title( 'A combination regression function and the observations' )
# Out:
# Text(0.5, 1.0, 'A combination regression function and the observations')

# %%
#. lets see how my model performs for the training set(blue)
mse(
y_sample,
model.predict( np.array(X_sample).reshape(-1,1) )
)
# Out:
# 0.5038630780742012

# %%
#lets draw another sample and make it my test set
sample_size = 10**4
population_size = len(X)

X_test = X.sample( frac = sample_size / population_size )
y_test = y.iloc[X_test.index]

# %%
#. now I can see how my model performs against new data
mse(
y_test,
model.predict( np.array(X_test).reshape(-1,1) )
)
# Out:
# 0.4872988891396017

# %% [markdown]
# I have some mean squared error scores for the training set and the test set for a single model

# %% [markdown]
# Since I do not have anything to compare to, I do not know if my linear model performs well or poorly...

# %% [markdown]
# #Now lets make this more flexible

# %%
#. To make this model more flexible I have exract some polynomial (non-linear) features of the data
#.   maybe I can just catch the trig curves?
from sklearn.preprocessing import PolynomialFeatures

Model_perf = {}

for i in range(1,250):

  poly = PolynomialFeatures(
                            degree = i,
                            include_bias = True,
                            ).fit_transform(
                                            np.array(X_sample).reshape(-1,1)
                                            )

  #. a new model with three features (non-linear) and a single response
  model = LinearRegression().fit(
                                poly, #previously it was : np.array(X_sample).reshape(-1,1),
                                y_sample
                                )

  #. How does my model perform?
  #.    Training set
  traning_mse = mse(
  y_sample,
  model.predict( poly )
  )

  #.   Test set
  test_mse = mse(
  y_test,
  model.predict(
  PolynomialFeatures(
                            degree = i,
                            include_bias = True,
                            ).fit_transform(
                                            np.array(X_test).reshape(-1,1)
                                            )
  )
  )

  Model_perf[i] = (traning_mse,test_mse)

seri = pd.Series([Model_perf[i][1] for i in range(1,50+1)])

seri[seri == seri.min()].index[0] + 1
# Out:
# 17

# %%
seri
# Out:
# 0     0.487299
# 1     0.452453
# 2     0.444474
# 3     0.446147
# 4     0.442519
# 5     0.428058
# 6     0.431072
# 7     0.421499
# 8     0.402743
# 9     0.396424
# 10    0.330850
# 11    0.243063
# 12    0.242397
# 13    0.245199
# 14    0.245642
# 15    0.246728
# 16    0.217310
# 17    0.272333
# 18    0.385586
# 19    0.516904
# 20    0.548291
# 21    0.518385
# 22    0.473664
# 23    0.912336
# 24    0.931476
# 25    0.881701
# 26    0.821873
# 27    0.801570
# 28    0.833220
# 29    0.912003
# 30    0.794624
# 31    0.854448
# 32    0.955507
# 33    1.088359
# 34    1.239750
# 35    1.392612
# 36    1.530296
# 37    1.647712
# 38    1.719565
# 39    1.718993
# 40    1.678403
# 41    1.518494
# 42    1.389902
# 43    1.421118
# 44    1.144197
# 45    1.029601
# 46    0.923835
# 47    0.929705
# 48    0.950613
# 49    0.994675
# dtype: float64

# %%
seri.min()
# Out:
# 0.21731018195343127

# %%
poly = PolynomialFeatures(
                            degree = 18,
                            include_bias = True,
                            ).fit_transform(
                                            np.array(X_sample).reshape(-1,1)
                                            )

#. a new model with three features (non-linear) and a single response
model = LinearRegression().fit(
                                poly, #previously it was : np.array(X_sample).reshape(-1,1),
                                y_sample
                                )

# %%
#. plotting the model
'''sns.scatterplot(
x = X_sample,
y = model.predict( poly ),
alpha = .1,
label = '$\hat y_{sample}$'
)'''
sns.lineplot(
x = X,
y = model.predict(
                  PolynomialFeatures(
                                    degree = 18,
                                    include_bias = True,
                                    ).fit_transform(
                                                    np.array(X).reshape(-1,1)
                                                    )
                  ),
alpha = .1,
label = '$\hat f(x)$'
)


###############PREVIOS PLOT##################

#. plotting my model
#. Plotting the responses again...
#.   Plotting the regression function in red
sns.lineplot(
    #. Values for the horizontal axis:
    x = X,
    #. Values for the vertical axis:
    y = f(X),
    color = 'red',
    alpha = .1,
    label = '$f(x)$'
)

#.   Plotting the responses in blue:
sns.scatterplot(
    #. Values for the horizontal axis:
    x = X_sample,
    #. Values for the vertical axis:
    y = y_sample,
    color = 'red',
    alpha = .2,
    marker = 'x',
    label = '$y_{sample}$'
)

#.   Plotting deviations from the reg. function
for i in X_sample.index:
  sns.lineplot(
  x = [X_sample[i],X_sample[i]],
  y = [y_sample[i],f( X_sample[i] )],
  color = 'black',

  )

#. Renaming axes
plt.xlabel( '$x_{sample}$' )
plt.ylabel( '$y_{sample}$' )

#. Plot title
plt.title( 'A combination regression function and the observations' )
# Out:
# Text(0.5, 1.0, 'A combination regression function and the observations')

# %%
#. Comparing the 12th degree poly_ mean squared error against the irreducible error (noise error)

mse(
y_test,
f( X_test )
)
# Out:
# 0.06227408287088355

# %% [markdown]
# #. Episode 2: Using a non-parametric model = K-Nearest Neighbor Regressor

# %%
sns.scatterplot(
    x = X,
    y = y)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
#. Getting some number of points in a sample
sample_size = 250
X_train = X.sample( frac = sample_size / len(X) )
X_train
# Out:
# 44603    2.291293
# 58311    3.456485
# 416     -1.464640
# 26550    0.756773
# 65432    4.061776
#            ...
# 78663    5.186422
# 80488    5.341548
# 36629    1.613496
# 88157    5.993420
# 83584    5.604711
# Length: 250, dtype: float64

# %%
X_train.index
# Out:
# Index([44603, 58311,   416, 26550, 65432,   773, 84298, 92711, 55917, 71084,
#        ...
#        85239, 92324, 34376, 91812, 57084, 78663, 80488, 36629, 88157, 83584],
#       dtype='int64', length=250)

# %%
y_train = y.loc[X_train.index]
y_train
# Out:
# 44603    0.856457
# 58311    2.277844
# 416     -1.331981
# 26550    1.422280
# 65432    0.470589
#            ...
# 78663    1.330938
# 80488    1.387539
# 36629    0.757217
# 88157    1.987766
# 83584    2.769302
# Length: 250, dtype: float64

# %%
#  Draw out a test set of size = 200
#.   Eliminate the observations in the training set
X_test = X.loc[ [i for i in X.index if i not in X_train.index] ].sample( frac = 200 / len( X.loc[ [i for i in X.index if i not in X_train.index] ] )  )

y_test = y.loc[ X_test.index ]
y_test
# Out:
# 56873    2.566060
# 41046    0.815681
# 43515    1.376617
# 61502    1.648705
# 51571    2.028612
#            ...
# 9147     0.626405
# 81431    1.436366
# 4108    -1.079407
# 91816    2.324320
# 85864    3.460230
# Length: 200, dtype: float64

# %%
#. plotting the training set
sns.scatterplot(
    x = X_train,
    y = y_train,
    label = 'training_set',
    alpha = 0.5
)
#. plotting the set set
sns.scatterplot(
    x = X_test,
    y = y_test,
    label = 'test_set',
    alpha = 0.5
)

plt.xlabel( 'Predictors' )
plt.ylabel( 'Response' )
# Out:
# Text(0, 0.5, 'Response')

# %%
#. Importing the KNN Regression function within the sklearn.neighbors submodule
from sklearn.neighbors import KNeighborsRegressor

# %%
type( X_train )
# Out:
# pandas.core.series.Series

# %%
model = KNeighborsRegressor( n_neighbors = len( X_train) ).fit(
                                                              np.array(X_train).reshape(-1, 1),
                                                              y_train
                                                              )
y_pred = model.predict( np.array(X_test).reshape(-1, 1) )

#. Plot the test set performance of the KNN regressor
sns.scatterplot(
x = X_test,
y = y_test,
label = 'Original test set responses'
)
sns.scatterplot(
x = X_test,
y = y_pred,
label = 'KNN predictions'
)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %%
#. Finding the best K-decisiton

#.   to record the mean squared error values in the loop
MSE = {}
#.   Form a loop that tries a number K:
for K in range(1, len(X_train)+1):

  model = KNeighborsRegressor( n_neighbors = K ).fit(
                                                    np.array(X_train).reshape(-1, 1),
                                                    y_train
                                                    )
  y_pred = model.predict( np.array(X_test).reshape(-1, 1) )
  MSE[K] = mse( y_test, y_pred )

MSE
# Out:
# {1: 0.13163714156698766,
#  2: 0.09824243712300461,
#  3: 0.08476473625673339,
#  4: 0.0871710384667561,
#  5: 0.08888829153043255,
#  6: 0.09098109308825507,
#  7: 0.08637871460448002,
#  8: 0.08733396495696079,
#  9: 0.09191982751780736,
#  10: 0.09234447740502418,
#  11: 0.09222292052142507,
#  12: 0.09454042959168678,
#  13: 0.10014895675918922,
#  14: 0.10558202278169458,
#  15: 0.11590981498508132,
#  16: 0.12023952922593534,
#  17: 0.13049405075190093,
#  18: 0.14275885325059312,
#  19: 0.15511341327221934,
#  20: 0.16759073565295904,
#  21: 0.17879868415091793,
#  22: 0.19269043074944242,
#  23: 0.21121814532290592,
#  24: 0.2285363969446069,
#  25: 0.24462031514680388,
#  26: 0.26109736428971053,
#  27: 0.2752447243287396,
#  28: 0.29010365711447966,
#  29: 0.305477747640807,
#  30: 0.3147369367155856,
#  31: 0.32699231277372354,
#  32: 0.33812546324695597,
#  33: 0.34779152577951733,
#  34: 0.3584594754784933,
#  35: 0.367726495715346,
#  36: 0.3785837317495585,
# ...

# %%
MSE = pd.Series(MSE)
sns.lineplot(MSE)
# Out:
# <Axes: >

# %%
MSE[ MSE == MSE.min() ]
# Out:
# 3    0.084765
# dtype: float64

# %%
#. K = 3 version of the KNN Regressor
model = KNeighborsRegressor( n_neighbors = 3 ).fit(
                                                  np.array(X_train).reshape(-1, 1),
                                                  y_train
                                                  )
y_pred = model.predict( np.array(X_test).reshape(-1, 1) )

#. Plot the test set performance of the KNN regressor
sns.scatterplot(
x = X_test,
y = y_test,
alpha = .1,
label = 'Original test set responses'
)
sns.lineplot(
x = X,
y = model.predict( np.array(X).reshape(-1, 1) ),
label = 'KNN predictions'
)
sns.lineplot(
x = X,
y = f(X),
label = 'Regression function',
alpha = 0.3
)
# Out:
# <Axes: xlabel='None', ylabel='None'>
